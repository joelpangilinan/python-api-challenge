# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 633

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Verify if I have my API key
print(weather_api_key)
# Out:
# eb944c662b7aab4ab942ee1f1817d3f8

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key
# url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    # city_url = url + "&q" + city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taoudenni
# Processing Record 2 of Set 1 | caravelas
# Processing Record 3 of Set 1 | ponta do sol
# Processing Record 4 of Set 1 | dhidhdhoo
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | bambanglipuro
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | yen bai
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | carnarvon
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | san andres
# Processing Record 17 of Set 1 | sabha
# Processing Record 18 of Set 1 | jamkhed
# Processing Record 19 of Set 1 | freeport
# Processing Record 20 of Set 1 | yanam
# Processing Record 21 of Set 1 | campbell river
# Processing Record 22 of Set 1 | constitucion
# Processing Record 23 of Set 1 | dong hoi
# Processing Record 24 of Set 1 | aroeiras
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | petropavl
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | aklavik
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | mangan
# Processing Record 31 of Set 1 | saskylakh
# Processing Record 32 of Set 1 | kostomuksha
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | mackenzie
# Processing Record 36 of Set 1 | kununurra
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | torbay
# Processing Record 39 of Set 1 | nanlong
# Processing Record 40 of Set 1 | college
# Processing Record 41 of Set 1 | diofior
# Processing Record 42 of Set 1 | bandarbeyla
# Processing Record 43 of Set 1 | pitsunda
# Processing Record 44 of Set 1 | kodiak
# Processing Record 45 of Set 1 | castleblayney
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | buluang
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | saint anthony
# Processing Record 50 of Set 1 | plettenberg bay
# Processing Record 0 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 2 | longyearbyen
# Processing Record 2 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | morros
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 2 | santa maria
# Processing Record 7 of Set 2 | vrangel
# Processing Record 8 of Set 2 | tiksi
# Processing Record 9 of Set 2 | ushuaia
# Processing Record 10 of Set 2 | saint-philippe
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | coro
# Processing Record 13 of Set 2 | kavieng
# Processing Record 14 of Set 2 | talnakh
# Processing Record 15 of Set 2 | cabo san lucas
# Processing Record 16 of Set 2 | tazmalt
# Processing Record 17 of Set 2 | raga
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | panzhihua
# Processing Record 22 of Set 2 | bethel
# Processing Record 23 of Set 2 | armidale
# Processing Record 24 of Set 2 | ilulissat
# Processing Record 25 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 2 | hilo
# Processing Record 27 of Set 2 | bengkulu
# Processing Record 28 of Set 2 | kuruman
# Processing Record 29 of Set 2 | katsuura
# Processing Record 30 of Set 2 | san jose
# Processing Record 31 of Set 2 | oranjemund
# Processing Record 32 of Set 2 | livingston
# Processing Record 33 of Set 2 | lasa
# Processing Record 34 of Set 2 | avarua
# Processing Record 35 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 36 of Set 2 | nuuk
# Processing Record 37 of Set 2 | mayo
# Processing Record 38 of Set 2 | puerto madero
# Processing Record 39 of Set 2 | samarinda
# Processing Record 40 of Set 2 | pevek
# Processing Record 41 of Set 2 | havre-saint-pierre
# Processing Record 42 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 2 | georgetown
# Processing Record 44 of Set 2 | ugoofaaru
# Processing Record 45 of Set 2 | bure
# Processing Record 46 of Set 2 | idanre
# Processing Record 47 of Set 2 | castro
# Processing Record 48 of Set 2 | mahebourg
# Processing Record 49 of Set 2 | soyo
# Processing Record 0 of Set 3 | hithadhoo
# Processing Record 1 of Set 3 | ahipara
# Processing Record 2 of Set 3 | rosarito
# Processing Record 3 of Set 3 | mayumba
# Processing Record 4 of Set 3 | copiapo
# Processing Record 5 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 3 | mega
# Processing Record 7 of Set 3 | qui nhon
# Processing Record 8 of Set 3 | saldanha
# Processing Record 9 of Set 3 | cozumel
# Processing Record 10 of Set 3 | paamiut
# Processing Record 11 of Set 3 | senneterre
# Processing Record 12 of Set 3 | umm kaddadah
# Processing Record 13 of Set 3 | dudinka
# Processing Record 14 of Set 3 | rantepao
# Processing Record 15 of Set 3 | clyde river
# Processing Record 16 of Set 3 | ribeira grande
# Processing Record 17 of Set 3 | bonthe
# Processing Record 18 of Set 3 | waipawa
# Processing Record 19 of Set 3 | nome
# Processing Record 20 of Set 3 | cherskiy
# Processing Record 21 of Set 3 | emba
# Processing Record 22 of Set 3 | svetlaya
# Processing Record 23 of Set 3 | trinidad
# Processing Record 24 of Set 3 | tuatapere
# Processing Record 25 of Set 3 | stephenville
# Processing Record 26 of Set 3 | fortuna
# Processing Record 27 of Set 3 | tilichiki
# Processing Record 28 of Set 3 | sinnamary
# Processing Record 29 of Set 3 | aksu
# Processing Record 30 of Set 3 | port lincoln
# Processing Record 31 of Set 3 | barrow
# Processing Record 32 of Set 3 | huarmey
# Processing Record 33 of Set 3 | tura
# Processing Record 34 of Set 3 | vesoul
# Processing Record 35 of Set 3 | saint george
# Processing Record 36 of Set 3 | ambon
# Processing Record 37 of Set 3 | quelimane
# Processing Record 38 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 3 | mufumbwe
# Processing Record 40 of Set 3 | alim
# Processing Record 41 of Set 3 | auki
# Processing Record 42 of Set 3 | beloha
# Processing Record 43 of Set 3 | gusau
# Processing Record 44 of Set 3 | hervey bay
# Processing Record 45 of Set 3 | erzin
# Processing Record 46 of Set 3 | snyder
# Processing Record 47 of Set 3 | mar del plata
# Processing Record 48 of Set 3 | alto longa
# Processing Record 49 of Set 3 | kirakira
# Processing Record 0 of Set 4 | dikson
# Processing Record 1 of Set 4 | malindi
# Processing Record 2 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 3 of Set 4 | hals
# Processing Record 4 of Set 4 | sitka
# Processing Record 5 of Set 4 | acarau
# Processing Record 6 of Set 4 | salalah
# Processing Record 7 of Set 4 | samandag
# Processing Record 8 of Set 4 | pisco
# Processing Record 9 of Set 4 | tuktoyaktuk
# Processing Record 10 of Set 4 | arak
# Processing Record 11 of Set 4 | zyryanka
# Processing Record 12 of Set 4 | margate
# Processing Record 13 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 4 | lavrentiya
# Processing Record 15 of Set 4 | kaliganj
# Processing Record 16 of Set 4 | tasiilaq
# Processing Record 17 of Set 4 | naron
# Processing Record 18 of Set 4 | coihaique
# Processing Record 19 of Set 4 | chokurdakh
# Processing Record 20 of Set 4 | upernavik
# Processing Record 21 of Set 4 | severo-kurilsk
# Processing Record 22 of Set 4 | balkanabat
# Processing Record 23 of Set 4 | peniche
# Processing Record 24 of Set 4 | khatanga
# Processing Record 25 of Set 4 | hambantota
# Processing Record 26 of Set 4 | jacksonville beach
# Processing Record 27 of Set 4 | provideniya
# Processing Record 28 of Set 4 | hirara
# Processing Record 29 of Set 4 | lompoc
# Processing Record 30 of Set 4 | bathsheba
# Processing Record 31 of Set 4 | anadyr
# Processing Record 32 of Set 4 | kumluca
# Processing Record 33 of Set 4 | tigil
# Processing Record 34 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 4 | kapaa
# Processing Record 37 of Set 4 | sungaipenuh
# Processing Record 38 of Set 4 | puerto ayora
# Processing Record 39 of Set 4 | gardabani
# Processing Record 40 of Set 4 | yandyki
# Processing Record 41 of Set 4 | faya
# Processing Record 42 of Set 4 | atlantic beach
# Processing Record 43 of Set 4 | bocas del toro
# Processing Record 44 of Set 4 | port shepstone
# Processing Record 45 of Set 4 | teya
# Processing Record 46 of Set 4 | vila
# Processing Record 47 of Set 4 | vega de alatorre
# Processing Record 48 of Set 4 | stokmarknes
# Processing Record 49 of Set 4 | cururupu
# Processing Record 0 of Set 5 | norman wells
# Processing Record 1 of Set 5 | chuy
# Processing Record 2 of Set 5 | chany
# Processing Record 3 of Set 5 | zharkent
# Processing Record 4 of Set 5 | lamu
# Processing Record 5 of Set 5 | seoul
# Processing Record 6 of Set 5 | ovre ardal
# Processing Record 7 of Set 5 | bonfim
# Processing Record 8 of Set 5 | lebu
# Processing Record 9 of Set 5 | cap-aux-meules
# Processing Record 10 of Set 5 | nabire
# Processing Record 11 of Set 5 | hohhot
# Processing Record 12 of Set 5 | oistins
# Processing Record 13 of Set 5 | diego de almagro
# Processing Record 14 of Set 5 | sumbe
# Processing Record 15 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 16 of Set 5 | maumere
# Processing Record 17 of Set 5 | new norfolk
# Processing Record 18 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 5 | luganville
# Processing Record 20 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 5 | meadow lake
# Processing Record 22 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 23 of Set 5 | dakar
# Processing Record 24 of Set 5 | richards bay
# Processing Record 25 of Set 5 | padang
# Processing Record 26 of Set 5 | piritiba
# Processing Record 27 of Set 5 | cidreira
# Processing Record 28 of Set 5 | port blair
# Processing Record 29 of Set 5 | san patricio
# Processing Record 30 of Set 5 | pasighat
# Processing Record 31 of Set 5 | genova
# Processing Record 32 of Set 5 | zhangye
# Processing Record 33 of Set 5 | sakakah
# Processing Record 34 of Set 5 | nikolayevka
# Processing Record 35 of Set 5 | pangnirtung
# Processing Record 36 of Set 5 | evensk
# Processing Record 37 of Set 5 | sobolevo
# Processing Record 38 of Set 5 | umea
# Processing Record 39 of Set 5 | naze
# Processing Record 40 of Set 5 | sola
# Processing Record 41 of Set 5 | thompson
# Processing Record 42 of Set 5 | katha
# City not found. Skipping...
# Processing Record 43 of Set 5 | borogontsy
# Processing Record 44 of Set 5 | eureka
# Processing Record 45 of Set 5 | byron bay
# Processing Record 46 of Set 5 | luderitz
# Processing Record 47 of Set 5 | atasu
# Processing Record 48 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 5 | bonavista
# Processing Record 0 of Set 6 | muros
# Processing Record 1 of Set 6 | arraial do cabo
# Processing Record 2 of Set 6 | narsaq
# Processing Record 3 of Set 6 | vestmannaeyjar
# Processing Record 4 of Set 6 | coquimbo
# Processing Record 5 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 6 of Set 6 | kualakapuas
# Processing Record 7 of Set 6 | esil
# Processing Record 8 of Set 6 | balaipungut
# Processing Record 9 of Set 6 | geraldton
# Processing Record 10 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 6 | palana
# Processing Record 12 of Set 6 | oga
# Processing Record 13 of Set 6 | prestea
# Processing Record 14 of Set 6 | iquitos
# Processing Record 15 of Set 6 | mongo
# Processing Record 16 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 6 | henties bay
# Processing Record 18 of Set 6 | bougouni
# Processing Record 19 of Set 6 | luanda
# Processing Record 20 of Set 6 | toplita
# City not found. Skipping...
# Processing Record 21 of Set 6 | grand gaube
# Processing Record 22 of Set 6 | mao
# Processing Record 23 of Set 6 | praya
# Processing Record 24 of Set 6 | verkhnyaya inta
# Processing Record 25 of Set 6 | san quintin
# Processing Record 26 of Set 6 | hasaki
# Processing Record 27 of Set 6 | te anau
# Processing Record 28 of Set 6 | sao joao da barra
# Processing Record 29 of Set 6 | poyarkovo
# Processing Record 30 of Set 6 | kasongo-lunda
# Processing Record 31 of Set 6 | harper
# Processing Record 32 of Set 6 | mezhdurechensk
# Processing Record 33 of Set 6 | batticaloa
# Processing Record 34 of Set 6 | saint-francois
# Processing Record 35 of Set 6 | porto novo
# Processing Record 36 of Set 6 | sarakhs
# Processing Record 37 of Set 6 | kahului
# Processing Record 38 of Set 6 | nantucket
# Processing Record 39 of Set 6 | songjianghe
# Processing Record 40 of Set 6 | san cristobal
# Processing Record 41 of Set 6 | viedma
# Processing Record 42 of Set 6 | klaksvik
# Processing Record 43 of Set 6 | santa rosa
# Processing Record 44 of Set 6 | chapleau
# Processing Record 45 of Set 6 | general roca
# Processing Record 46 of Set 6 | touros
# Processing Record 47 of Set 6 | comodoro rivadavia
# Processing Record 48 of Set 6 | fare
# Processing Record 49 of Set 6 | odesskoye
# Processing Record 0 of Set 7 | springfield
# Processing Record 1 of Set 7 | westport
# Processing Record 2 of Set 7 | jijiga
# Processing Record 3 of Set 7 | esperance
# Processing Record 4 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 7 | kruisfontein
# Processing Record 6 of Set 7 | saint-augustin
# Processing Record 7 of Set 7 | puerto colombia
# Processing Record 8 of Set 7 | dimbokro
# Processing Record 9 of Set 7 | port elizabeth
# Processing Record 10 of Set 7 | omboue
# Processing Record 11 of Set 7 | concordia
# Processing Record 12 of Set 7 | shestakovo
# Processing Record 13 of Set 7 | acapulco
# Processing Record 14 of Set 7 | soledade
# Processing Record 15 of Set 7 | kudahuvadhoo
# Processing Record 16 of Set 7 | wanning
# Processing Record 17 of Set 7 | adrar
# Processing Record 18 of Set 7 | cam ranh
# Processing Record 19 of Set 7 | ust-nera
# Processing Record 20 of Set 7 | nanortalik
# Processing Record 21 of Set 7 | coracao de jesus
# Processing Record 22 of Set 7 | ambanja
# Processing Record 23 of Set 7 | lata
# Processing Record 24 of Set 7 | huambo
# Processing Record 25 of Set 7 | salina
# Processing Record 26 of Set 7 | taunggyi
# Processing Record 27 of Set 7 | isangel
# Processing Record 28 of Set 7 | beyla
# Processing Record 29 of Set 7 | sadat
# Processing Record 30 of Set 7 | kurikka
# Processing Record 31 of Set 7 | sonegaon
# Processing Record 32 of Set 7 | dingle
# Processing Record 33 of Set 7 | lalgudi
# Processing Record 34 of Set 7 | shingu
# Processing Record 35 of Set 7 | saint-pierre
# Processing Record 36 of Set 7 | tiarei
# Processing Record 37 of Set 7 | kupang
# Processing Record 38 of Set 7 | takoradi
# Processing Record 39 of Set 7 | port hueneme
# Processing Record 40 of Set 7 | bukama
# Processing Record 41 of Set 7 | collie
# Processing Record 42 of Set 7 | tall kayf
# Processing Record 43 of Set 7 | alice springs
# Processing Record 44 of Set 7 | talsi
# Processing Record 45 of Set 7 | palu
# Processing Record 46 of Set 7 | ostrovnoy
# Processing Record 47 of Set 7 | tolaga bay
# Processing Record 48 of Set 7 | hede
# Processing Record 49 of Set 7 | suzhou
# Processing Record 0 of Set 8 | piacabucu
# Processing Record 1 of Set 8 | namibe
# Processing Record 2 of Set 8 | husavik
# Processing Record 3 of Set 8 | krasnogvardeyskiy
# Processing Record 4 of Set 8 | novyy urengoy
# Processing Record 5 of Set 8 | mayor pablo lagerenza
# Processing Record 6 of Set 8 | vardo
# Processing Record 7 of Set 8 | arkhara
# Processing Record 8 of Set 8 | kandrian
# Processing Record 9 of Set 8 | vila franca do campo
# Processing Record 10 of Set 8 | ochamchira
# Processing Record 11 of Set 8 | la ronge
# Processing Record 12 of Set 8 | asayita
# City not found. Skipping...
# Processing Record 13 of Set 8 | sawtell
# Processing Record 14 of Set 8 | buala
# Processing Record 15 of Set 8 | krutinka
# Processing Record 16 of Set 8 | puchezh
# Processing Record 17 of Set 8 | degtyarsk
# Processing Record 18 of Set 8 | mount isa
# Processing Record 19 of Set 8 | ovsyanka
# Processing Record 20 of Set 8 | iqaluit
# Processing Record 21 of Set 8 | lyuban
# Processing Record 22 of Set 8 | xinzhou
# Processing Record 23 of Set 8 | minna
# Processing Record 24 of Set 8 | kargapolye
# City not found. Skipping...
# Processing Record 25 of Set 8 | chaihe
# Processing Record 26 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 8 | morro bay
# Processing Record 28 of Set 8 | ballangen
# Processing Record 29 of Set 8 | victoria
# Processing Record 30 of Set 8 | dicabisagan
# Processing Record 31 of Set 8 | carutapera
# Processing Record 32 of Set 8 | aleksandrov gay
# Processing Record 33 of Set 8 | viesca
# Processing Record 34 of Set 8 | the pas
# Processing Record 35 of Set 8 | los llanos de aridane
# Processing Record 36 of Set 8 | kaitangata
# Processing Record 37 of Set 8 | puerto escondido
# Processing Record 38 of Set 8 | ulaangom
# Processing Record 39 of Set 8 | saint-georges
# Processing Record 40 of Set 8 | ixtapa
# Processing Record 41 of Set 8 | zmiyiv
# Processing Record 42 of Set 8 | rodrigues alves
# Processing Record 43 of Set 8 | machinga
# Processing Record 44 of Set 8 | christchurch
# Processing Record 45 of Set 8 | chernukha
# Processing Record 46 of Set 8 | portland
# Processing Record 47 of Set 8 | leshukonskoye
# Processing Record 48 of Set 8 | hami
# Processing Record 49 of Set 8 | surt
# Processing Record 0 of Set 9 | yar-sale
# Processing Record 1 of Set 9 | port-gentil
# Processing Record 2 of Set 9 | flinders
# Processing Record 3 of Set 9 | kolodeznyy
# Processing Record 4 of Set 9 | santa isabel do rio negro
# Processing Record 5 of Set 9 | pathein
# Processing Record 6 of Set 9 | potma
# City not found. Skipping...
# Processing Record 7 of Set 9 | porto torres
# Processing Record 8 of Set 9 | mogadishu
# Processing Record 9 of Set 9 | yokadouma
# Processing Record 10 of Set 9 | dmitriyevka
# Processing Record 11 of Set 9 | airai
# Processing Record 12 of Set 9 | aldan
# Processing Record 13 of Set 9 | cayenne
# Processing Record 14 of Set 9 | gorodishche
# Processing Record 15 of Set 9 | kloulklubed
# Processing Record 16 of Set 9 | shimanovsk
# Processing Record 17 of Set 9 | goundam
# Processing Record 18 of Set 9 | larsnes
# Processing Record 19 of Set 9 | lorengau
# Processing Record 20 of Set 9 | tomatlan
# Processing Record 21 of Set 9 | tual
# Processing Record 22 of Set 9 | bam
# Processing Record 23 of Set 9 | kashi
# Processing Record 24 of Set 9 | ginir
# Processing Record 25 of Set 9 | imbituba
# Processing Record 26 of Set 9 | mananjary
# Processing Record 27 of Set 9 | bud
# Processing Record 28 of Set 9 | payo
# Processing Record 29 of Set 9 | mindelheim
# Processing Record 30 of Set 9 | lingao
# Processing Record 31 of Set 9 | la romana
# Processing Record 32 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 9 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 34 of Set 9 | yaransk
# Processing Record 35 of Set 9 | port maria
# Processing Record 36 of Set 9 | codrington
# Processing Record 37 of Set 9 | leningradskiy
# Processing Record 38 of Set 9 | broken hill
# Processing Record 39 of Set 9 | tailai
# Processing Record 40 of Set 9 | demba
# Processing Record 41 of Set 9 | pinawa
# Processing Record 42 of Set 9 | witney
# Processing Record 43 of Set 9 | kendari
# Processing Record 44 of Set 9 | athabasca
# Processing Record 45 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 9 | soe
# Processing Record 47 of Set 9 | alta floresta
# Processing Record 48 of Set 9 | abu dhabi
# Processing Record 49 of Set 9 | mahajanga
# Processing Record 0 of Set 10 | aykhal
# Processing Record 1 of Set 10 | edgewater
# Processing Record 2 of Set 10 | waingapu
# Processing Record 3 of Set 10 | damghan
# Processing Record 4 of Set 10 | sinnai
# Processing Record 5 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 10 | morondava
# Processing Record 7 of Set 10 | agadez
# Processing Record 8 of Set 10 | berlevag
# Processing Record 9 of Set 10 | ouegoa
# Processing Record 10 of Set 10 | maxixe
# Processing Record 11 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 12 of Set 10 | rio gallegos
# Processing Record 13 of Set 10 | nova olimpia
# Processing Record 14 of Set 10 | souillac
# Processing Record 15 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 16 of Set 10 | presidente medici
# Processing Record 17 of Set 10 | khromtau
# Processing Record 18 of Set 10 | worthington
# Processing Record 19 of Set 10 | belgrade
# Processing Record 20 of Set 10 | vanimo
# Processing Record 21 of Set 10 | grindavik
# Processing Record 22 of Set 10 | poplar bluff
# Processing Record 23 of Set 10 | wabash
# Processing Record 24 of Set 10 | avallon
# Processing Record 25 of Set 10 | ngunguru
# Processing Record 26 of Set 10 | sulangan
# Processing Record 27 of Set 10 | contamana
# Processing Record 28 of Set 10 | thunder bay
# Processing Record 29 of Set 10 | challans
# Processing Record 30 of Set 10 | harindanga
# Processing Record 31 of Set 10 | avera
# Processing Record 32 of Set 10 | antofagasta
# Processing Record 33 of Set 10 | mbanza-ngungu
# Processing Record 34 of Set 10 | bubaque
# Processing Record 35 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 10 | valkeakoski
# Processing Record 37 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 38 of Set 10 | yakeshi
# Processing Record 39 of Set 10 | veraval
# Processing Record 40 of Set 10 | volkermarkt
# City not found. Skipping...
# Processing Record 41 of Set 10 | tiznit
# Processing Record 42 of Set 10 | tessalit
# Processing Record 43 of Set 10 | rognan
# Processing Record 44 of Set 10 | ancud
# Processing Record 45 of Set 10 | villamontes
# Processing Record 46 of Set 10 | faanui
# Processing Record 47 of Set 10 | veselynove
# Processing Record 48 of Set 10 | bulolo
# Processing Record 49 of Set 10 | koslan
# Processing Record 0 of Set 11 | voskresenskoye
# Processing Record 1 of Set 11 | kaeo
# Processing Record 2 of Set 11 | beidao
# Processing Record 3 of Set 11 | ilhabela
# Processing Record 4 of Set 11 | chapais
# Processing Record 5 of Set 11 | haimen
# Processing Record 6 of Set 11 | guarapari
# Processing Record 7 of Set 11 | kankavli
# City not found. Skipping...
# Processing Record 8 of Set 11 | canutama
# Processing Record 9 of Set 11 | ibra
# Processing Record 10 of Set 11 | idrinskoye
# Processing Record 11 of Set 11 | hire
# City not found. Skipping...
# Processing Record 12 of Set 11 | purranque
# Processing Record 13 of Set 11 | sayhat
# Processing Record 14 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 11 | nkhata bay
# Processing Record 16 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 17 of Set 11 | coolum beach
# Processing Record 18 of Set 11 | copandaro
# City not found. Skipping...
# Processing Record 19 of Set 11 | maningrida
# Processing Record 20 of Set 11 | porto velho
# Processing Record 21 of Set 11 | pailon
# Processing Record 22 of Set 11 | hammerfest
# Processing Record 23 of Set 11 | jiazi
# Processing Record 24 of Set 11 | ipanema
# Processing Record 25 of Set 11 | tyrma
# Processing Record 26 of Set 11 | caala
# Processing Record 27 of Set 11 | tabas
# Processing Record 28 of Set 11 | sai buri
# Processing Record 29 of Set 11 | san juan de uraba
# Processing Record 30 of Set 11 | svetlyy
# Processing Record 31 of Set 11 | culiacan
# Processing Record 32 of Set 11 | boffa
# Processing Record 33 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 34 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 35 of Set 11 | khawhai
# Processing Record 36 of Set 11 | spirit river
# Processing Record 37 of Set 11 | bajil
# Processing Record 38 of Set 11 | roebourne
# Processing Record 39 of Set 11 | talara
# Processing Record 40 of Set 11 | plouzane
# Processing Record 41 of Set 11 | phetchaburi
# Processing Record 42 of Set 11 | limbang
# Processing Record 43 of Set 11 | bambous virieux
# Processing Record 44 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 45 of Set 11 | fairbanks
# Processing Record 46 of Set 11 | simbahan
# Processing Record 47 of Set 11 | yulara
# Processing Record 48 of Set 11 | duminichi
# Processing Record 49 of Set 11 | bimbo
# Processing Record 0 of Set 12 | djambala
# Processing Record 1 of Set 12 | banmo
# City not found. Skipping...
# Processing Record 2 of Set 12 | picos
# Processing Record 3 of Set 12 | broome
# Processing Record 4 of Set 12 | soderhamn
# Processing Record 5 of Set 12 | honningsvag
# Processing Record 6 of Set 12 | ravar
# Processing Record 7 of Set 12 | anar darreh
# City not found. Skipping...
# Processing Record 8 of Set 12 | colchester
# Processing Record 9 of Set 12 | kovernino
# Processing Record 10 of Set 12 | maniitsoq
# Processing Record 11 of Set 12 | mandalgovi
# Processing Record 12 of Set 12 | aguadilla
# Processing Record 13 of Set 12 | vila real de santo antonio
# Processing Record 14 of Set 12 | benicarlo
# Processing Record 15 of Set 12 | namatanai
# Processing Record 16 of Set 12 | dukat
# Processing Record 17 of Set 12 | urulga
# City not found. Skipping...
# Processing Record 18 of Set 12 | mugumu
# Processing Record 19 of Set 12 | barao de melgaco
# Processing Record 20 of Set 12 | the valley
# Processing Record 21 of Set 12 | cestas
# Processing Record 22 of Set 12 | puerto baquerizo moreno
# Processing Record 23 of Set 12 | asau
# Processing Record 24 of Set 12 | kharp
# Processing Record 25 of Set 12 | barra patuca
# Processing Record 26 of Set 12 | gigmoto
# Processing Record 27 of Set 12 | havelock
# Processing Record 28 of Set 12 | rennes
# Processing Record 29 of Set 12 | sept-iles
# Processing Record 30 of Set 12 | guerrero negro
# Processing Record 31 of Set 12 | mpanda
# Processing Record 32 of Set 12 | ozernovskiy
# Processing Record 33 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 12 | gasa
# Processing Record 35 of Set 12 | namwala
# Processing Record 36 of Set 12 | qandala
# Processing Record 37 of Set 12 | turukhansk
# Processing Record 38 of Set 12 | launceston
# Processing Record 39 of Set 12 | pionerskiy
# Processing Record 40 of Set 12 | dharchula
# Processing Record 41 of Set 12 | pinyug
# Processing Record 42 of Set 12 | santiago
# Processing Record 43 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 44 of Set 12 | sistranda
# Processing Record 45 of Set 12 | natchitoches
# Processing Record 46 of Set 12 | mvuma
# Processing Record 47 of Set 12 | remontnoye
# Processing Record 48 of Set 12 | almaznyy
# Processing Record 49 of Set 12 | andenes
# Processing Record 0 of Set 13 | ushtobe
# Processing Record 1 of Set 13 | meadville
# Processing Record 2 of Set 13 | vila velha
# Processing Record 3 of Set 13 | kuching
# Processing Record 4 of Set 13 | vao
# Processing Record 5 of Set 13 | kez
# Processing Record 6 of Set 13 | cassilandia
# Processing Record 7 of Set 13 | haines junction
# Processing Record 8 of Set 13 | lexington-fayette
# Processing Record 9 of Set 13 | grenfell
# Processing Record 10 of Set 13 | arlit
# Processing Record 11 of Set 13 | valparaiso
# Processing Record 12 of Set 13 | xuddur
# Processing Record 13 of Set 13 | great yarmouth
# Processing Record 14 of Set 13 | lucea
# Processing Record 15 of Set 13 | ballina
# Processing Record 16 of Set 13 | pimentel
# Processing Record 17 of Set 13 | batagay-alyta
# Processing Record 18 of Set 13 | kuntaur
# Processing Record 19 of Set 13 | aripuana
# Processing Record 20 of Set 13 | pathalgaon
# Processing Record 21 of Set 13 | ternate
# Processing Record 22 of Set 13 | birobidzhan
# Processing Record 23 of Set 13 | nemuro
# Processing Record 24 of Set 13 | lewistown
# Processing Record 25 of Set 13 | lityn
# Processing Record 26 of Set 13 | vostok
# Processing Record 27 of Set 13 | okhotsk
# Processing Record 28 of Set 13 | sarh
# Processing Record 29 of Set 13 | derbent
# Processing Record 30 of Set 13 | nur
# Processing Record 31 of Set 13 | doha
# Processing Record 32 of Set 13 | muroto
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          582
# Lat           582
# Lng           582
# Max Temp      582
# Humidity      582
# Cloudiness    582
# Wind Speed    582
# Country       582
# Date          582
# dtype: int64

# %%
# Convert max temp from fahrenheit to celsius
city_data_df["Max Temp"] = [(x-32) * 0.56 for x in city_data_df["Max Temp"]]

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     taoudenni  22.6783  -3.9836  143.9480        14           0        4.55
# 1     caravelas -17.7125 -39.2481  148.1648        95         100        2.60
# 2  ponta do sol  32.6667 -17.1000  145.2192        78          45        2.77
# 3     dhidhdhoo   6.8833  73.1000  149.7720        68          63        5.63
# 4        albany  42.6001 -73.9662  134.9320        79          99        2.67
#
#   Country        Date
# 0      ML  1674348872
# 1      BR  1674348873
# 2      PT  1674348874
# 3      MV  1674348874
# 4      US  1674348720

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           taoudenni  22.6783  -3.9836  143.9480        14           0
# 1           caravelas -17.7125 -39.2481  148.1648        95         100
# 2        ponta do sol  32.6667 -17.1000  145.2192        78          45
# 3           dhidhdhoo   6.8833  73.1000  149.7720        68          63
# 4              albany  42.6001 -73.9662  134.9320        79          99
#
#          Wind Speed Country        Date
# City_ID
# 0              4.55      ML  1674348872
# 1              2.60      BR  1674348873
# 2              2.77      PT  1674348874
# 3              5.63      MV  1674348874
# 4              2.67      US  1674348720

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.plot(city_data_df["Lat"], 
         city_data_df["Max Temp"], 
         linestyle="none", 
         marker="o", 
         markeredgecolor="black", 
         markeredgewidth=0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Latitude vs. Max Temperature (2023-01-24)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.plot(city_data_df["Lat"], 
         city_data_df["Humidity"], 
         linestyle="none", 
         marker="o", 
         markeredgecolor="black", 
         markeredgewidth=0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (2023-01-24)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.plot(city_data_df["Lat"], 
         city_data_df["Cloudiness"], 
         linestyle="none", 
         marker="o", 
         markeredgecolor="black", 
         markeredgewidth=0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness (2023-01-24)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.plot(city_data_df["Lat"], 
         city_data_df["Wind Speed"], 
         linestyle="none", 
         marker="o", 
         markeredgecolor="black", 
         markeredgewidth=0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed (2023-01-24)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(city_data_df["Lat"], city_data_df["Max Temp"])
regress_values = city_data_df["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Show the line equation
line_eq
# Out:
# 'y = -0.24x + 144.92'

# %%
regress_values
# Out:
# City_ID
# 0      139.480444
# 1      149.162359
# 2      137.086165
# 3      143.266599
# 4      134.705070
#           ...
# 577    142.724960
# 578    134.832666
# 579    132.291663
# 580    138.855195
# 581    136.938363
# Name: Lat, Length: 582, dtype: float64

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           taoudenni  22.6783   -3.9836  143.9480        14           0
# 2        ponta do sol  32.6667  -17.1000  145.2192        78          45
# 3           dhidhdhoo   6.8833   73.1000  149.7720        68          63
# 4              albany  42.6001  -73.9662  134.9320        79          99
# 5         yellowknife  62.4560 -114.3525  129.6176        85         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.55      ML  1674348872
# 2              2.77      PT  1674348874
# 3              5.63      MV  1674348874
# 4              2.67      US  1674348720
# 5              4.12      CA  1674348326

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            caravelas -17.7125  -39.2481  148.1648        95         100
# 6        bambanglipuro  -7.9500  110.2833  149.9008        80          24
# 8              rikitea -23.1203 -134.9692  149.3800        79         100
# 9          east london -33.0153   27.9116  148.7248        89         100
# 11             mataura -46.1927  168.8643  144.3064        48         100
#
#          Wind Speed Country        Date
# City_ID
# 1              2.60      BR  1674348873
# 6              2.06      ID  1674348875
# 8              8.00      PF  1674348875
# 9              3.60      ZA  1674348876
# 11             2.29      NZ  1674348877

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
regress_values = northern_hemi_df["Lat"] * slope + intercept
line_eq_northern_temp = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Determine the correlation
correlation_northern_temp = st.pearsonr(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])

# Create the plot
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(line_eq_northern_temp,(5,115),fontsize=15,color="red")
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
plt.plot(northern_hemi_df["Lat"],regress_values,"r-")
print(f"The r-value is: {correlation_northern_temp[0]}")
plt.show()
# Out:
# The r-value is: -0.8294931815632774

# %%
# Linear regression on Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
regress_values = southern_hemi_df["Lat"] * slope + intercept
line_eq_southern_temp = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Determine the correlation
correlation_southern_temp = st.pearsonr(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])

# Create the plot
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.annotate(line_eq_southern_temp,(-55,152),fontsize=15,color="red")
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
plt.plot(southern_hemi_df["Lat"],regress_values,"r-")
print(f"The r-value is: {correlation_southern_temp[0]}")
plt.show()
# Out:
# The r-value is: 0.42985551794531623

# %% [markdown]
# **Discussion about the linear relationship:** The "Temperature vs. Latitude Linear Regression Plots" have a strong negative correlation for northern latitudes and a weak positive correlation for southern latitudes

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
regress_values = northern_hemi_df["Lat"] * slope + intercept
line_eq_northern_humidity = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Determine the correlation
correlation_northern_humidity = st.pearsonr(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])

# Create the plot
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq_northern_humidity,(40,20),fontsize=15,color="red")
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
plt.plot(northern_hemi_df["Lat"],regress_values,"r-")
print(f"The r-value is: {correlation_northern_humidity[0]}")
plt.show()
# Out:
# The r-value is: 0.35037795104058994

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
regress_values = southern_hemi_df["Lat"] * slope + intercept
line_eq_southern_humidity = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Determine the correlation
correlation_southern_humidity = st.pearsonr(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])

# Create the plot
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.annotate(line_eq_southern_humidity,(-50,25),fontsize=15,color="red")
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
plt.plot(southern_hemi_df["Lat"],regress_values,"r-")
print(f"The r-value is: {correlation_southern_humidity[0]}")
plt.show()
# Out:
# The r-value is: 0.3315884424166424

# %% [markdown]
# **Discussion about the linear relationship:** Both the northern and southern latitudes have a weak positive correlation with humidity

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
regress_values = northern_hemi_df["Lat"] * slope + intercept
line_eq_northern_cloudiness = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Determine the correlation
correlation_northern_cloudiness = st.pearsonr(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])

# Create the plot
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq_northern_cloudiness,(40,20),fontsize=15,color="red")
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
plt.plot(northern_hemi_df["Lat"],regress_values,"r-")
print(f"The r-value is: {correlation_northern_cloudiness[0]}")
plt.show()
# Out:
# The r-value is: 0.3013610977717922

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
regress_values = southern_hemi_df["Lat"] * slope + intercept
line_eq_southern_cloudiness = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Determine the correlation
correlation_southern_cloudiness = st.pearsonr(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])

# Create the plot
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.annotate(line_eq_southern_cloudiness,(-55,10),fontsize=15,color="red")
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
plt.plot(southern_hemi_df["Lat"],regress_values,"r-")
print(f"The r-value is: {correlation_southern_cloudiness[0]}")
plt.show()
# Out:
# The r-value is: 0.24392559347581608

# %% [markdown]
# **Discussion about the linear relationship:** The nothern latitudes have a weak positive correlation with cloudiness while the southern latitudes have a very weak positive correlation with cloudiness

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
regress_values = northern_hemi_df["Lat"] * slope + intercept
line_eq_northern_wind = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Determine the correlation
correlation_northern_wind = st.pearsonr(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])

# Create the plot
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line_eq_northern_wind,(5,16),fontsize=15,color="red")
plt.scatter(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
plt.plot(northern_hemi_df["Lat"],regress_values,"r-")
print(f"The r-value is: {correlation_northern_wind[0]}")
plt.show()
# Out:
# The r-value is: 0.14164488099565742

# %%
# Southern Hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
regress_values = southern_hemi_df["Lat"] * slope + intercept
line_eq_southern_wind = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Determine the correlation
correlation_southern_wind = st.pearsonr(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])

# Create the plot
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.annotate(line_eq_southern_wind,(5,16),fontsize=15,color="red")
plt.scatter(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
plt.plot(southern_hemi_df["Lat"],regress_values,"r-")
print(f"The r-value is: {correlation_southern_wind[0]}")
plt.show()
# Out:
# The r-value is: -0.3815562043968311

# %% [markdown]
# **Discussion about the linear relationship:** The "Wind Speed vs. Latitude Linear Regression Plot" have a very weak positive correlation on northern latitudes and a weak negative correlation on southern latitudes
